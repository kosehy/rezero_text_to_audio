# %%
pip install scrapy pydub gtts
# Out:
# ...
#      |████████████████████████████████| 245kB 2.8MB/s
# ...
#      |████████████████████████████████| 3.1MB 7.6MB/s
# ...
#      |████████████████████████████████| 3.2MB 28.6MB/s
# ...
#      |████████████████████████████████| 2.7MB 43.9MB/s
# ...
#      |████████████████████████████████| 61kB 9.1MB/s
# ...
#      |████████████████████████████████| 235kB 38.8MB/s
# ...
#      |████████████████████████████████| 61kB 8.4MB/s
# ...
#   Created wheel for PyDispatcher: filename=PyDispatcher-2.0.5-cp36-none-any.whl size=11515 sha256=e7d314f5b279e13da89ab71be79cf382d95fb22f5a62ea0aac936c633bc11d6d
#   Stored in directory: /root/.cache/pip/wheels/88/99/96/cfef6665f9cb1522ee6757ae5955feedf2fe25f1737f91fa7f
# ...
#   Created wheel for protego: filename=Protego-0.1.16-cp36-none-any.whl size=7765 sha256=a49143d48f443fee7f24b31523f08a5045fa8fa99857d92a65f4856c6411e613
#   Stored in directory: /root/.cache/pip/wheels/51/01/d1/4a2286a976dccd025ba679acacfe37320540df0f2283ecab12
# ...

# %%
# !git clone https://github.com/kosehy/rezero_text_to_audio.git
# Out:
# Cloning into 'rezero_text_to_audio'...
# remote: Enumerating objects: 68, done.
# remote: Counting objects: 100% (68/68), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 68 (delta 34), reused 31 (delta 11), pack-reused 0
# Unpacking objects: 100% (68/68), done.

# %%
# %cd rezero_text_to_audio/
# Out:
# /content/rezero_text_to_audio

# %%
# !scrapy runspider generate_text.py
# Out:
# 2020-05-04 01:37:38 [scrapy.utils.log] INFO: Scrapy 2.1.0 started (bot: scrapybot)
# 2020-05-04 01:37:38 [scrapy.utils.log] INFO: Versions: lxml 4.2.6.0, libxml2 2.9.8, cssselect 1.1.0, parsel 1.5.2, w3lib 1.21.0, Twisted 20.3.0, Python 3.6.9 (default, Nov  7 2019, 10:44:02) - [GCC 8.3.0], pyOpenSSL 19.1.0 (OpenSSL 1.1.1g  21 Apr 2020), cryptography 2.9.2, Platform Linux-4.19.104+-x86_64-with-Ubuntu-18.04-bionic
# 2020-05-04 01:37:38 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2020-05-04 01:37:38 [scrapy.crawler] INFO: Overridden settings:
# {'SPIDER_LOADER_WARN_ONLY': True}
# 2020-05-04 01:37:38 [scrapy.extensions.telnet] INFO: Telnet Password: 946bddb8798f37ae
# 2020-05-04 01:37:38 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# ...

# %%
# !python3 generate_audio.py
# Out:
# 2020-05-04 01:30:18 [scrapy.utils.log] INFO: Scrapy 2.1.0 started (bot: scrapybot)
# 2020-05-04 01:30:18 [scrapy.utils.log] INFO: Versions: lxml 4.2.6.0, libxml2 2.9.8, cssselect 1.1.0, parsel 1.5.2, w3lib 1.21.0, Twisted 20.3.0, Python 3.6.9 (default, Nov  7 2019, 10:44:02) - [GCC 8.3.0], pyOpenSSL 19.1.0 (OpenSSL 1.1.1g  21 Apr 2020), cryptography 2.9.2, Platform Linux-4.19.104+-x86_64-with-Ubuntu-18.04-bionic
# 2020-05-04 01:30:18 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 0: 第一章１　　『ギザ十は使えない』
#
# 2020-05-04 01:30:18 [gtts.tts] DEBUG: tokenizer_func: <bound method Tokenizer.run of re.compile('(?<=\\?).|(?<=\\!).|(?<=\\？).|(?<=\\！).|(?<!\\.[a-z])\\. |(?<!\\.[a-z])\\, |(?<!\\d)\\:|\\)|\\¡|\\：|\\]|\\[|\\(|\\，|\\‥|\\;|\\¿|\\、|\\…|\\—|\\。|\\،|\\\n', re.IGNORECASE) from: [<function tone_marks at 0x7f694f25fae8>, <function period_comma at 0x7f694f25fb70>, <function colon at 0x7f694f25fbf8>, <function other_punctuation at 0x7f694f25fc80>]>
# ...

# %%
# !git config --global user.email "kosehy@gmail.com"
# !git config --global user.name "kosehy"

# %%
# !git commit -m "Update generate_text.py/Delete get_next_page.py"
# Out:
# [master 63c4cbb] Update generate_text.py/Delete get_next_page.py
#  2 files changed, 5 insertions(+), 52 deletions(-)
#  delete mode 100644 get_next_page.py

# %%
# !git remote rm origin

# %%
u = 'kosehy'; p = 'GIangelvani815!!';
# !git remote add origin https://$u:$p@github.com/$u/rezero_text_to_audio

# %%
# !git push --set-upstream origin master
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 360 bytes | 360.00 KiB/s, done.
# Total 3 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/kosehy/rezero_text_to_audio
#    d977a09..63c4cbb  master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.
